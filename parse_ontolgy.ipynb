# %%
import pandas as pd

from rdflib import Graph, URIRef, Literal, Namespace

from rdflib.namespace import XSD, RDF, RDFS, OWL, SKOS, PROV, DC

# %%
# Read the Excel file
xls = pd.ExcelFile('TIDO_ORSD.xlsx')

# Read the sheets into DataFrames
df_class = pd.read_excel(xls, 'Class definitions')
df_property = pd.read_excel(xls, 'Relation definitions')

# Set the second row as the column headers
df_class.columns = df_class.iloc[1]
df_class = df_class[2:].reset_index(drop=True)
df_class = df_class.rename_axis(None, axis=1)

df_property.columns = df_property.iloc[1]
df_property = df_property[2:].reset_index(drop=True)
df_property = df_property.rename_axis(None, axis=1)

# Display a DataFrame
df_property
# Out:
#                      Relation               Label(s)  \
# 0             tido:hasContext            has context
# 1               tido:disputes               disputes
# 2               tido:supports               supports
# 3   tido:providesInsightsInto  provides insight into
# 4                tido:assumes                assumes
# 5                tido:answers                answers
# 6              tido:questions              questions
# 7                tido:informs                informs
# 8       tido:hasConsideration      has consideration
# 9          tido:wasSelectedBy        was selected by
# 10         tido:wasExecutedBy        was executed by
# 11         tido:wasRecalledBy        was recalled by
# 12          tido:investigates           investigates
# 13         tido:contributesTo         contributes to
#
#                                            Definition  \
# 0   A relationship indicating how one piece of inf...
# 1   A relationship indicating how a piece of infor...
# 2   A relationship indicating how a piece of infor...
# 3   The super-property of tido:supports and tido:d...
# 4   A relationship indicating how an option would ...
# 5   A piece of information can be used to answer a...
# 6   A research question can be raised by a piece o...
# 7   A relationship that indicates which options wo...
# 8   An option can have multiple considerations tha...
# 9   An option can be selected during a resolution ...
# 10  Once an option is selected, it could be excecu...
# 11  During an orientation step, no new informatoin...
# 12  An investigation, or case, investigates one or...
# 13  Every activity should contribute to one or mor...
#
#                      Domain                    Range  \
# 0   tido:PieceOfInformation  tido:PieceOfInformation
# 1   tido:PieceOfInformation          tido:Hypothesis
# 2   tido:PieceOfInformation          tido:Hypothesis
# 3   tido:PieceOfInformation          tido:Hypothesis
# 4               tido:Option          tido:Hypothesis
# 5   tido:PieceOfInformation                  tido:RQ
# 6                   tido:RQ  tido:PieceOfInformation
# 7               tido:Option                  tido:RQ
# 8               tido:Option       tido:Consideration
# 9               tido:Option          tido:Resolution
# 10              tido:Option            tido:Activity
# 11  tido:PieceOfInformation         tido:Orientation
# 12                tido:Case                  tido:RQ
# 13            tido:Activity                tido:Case
#
#    Status (Proposed, Accepted, Rejected, Deprecated) Superseded by Comments  \
# 0                                                NaN           NaN      NaN
# 1                                                NaN           NaN      NaN
# 2                                                NaN           NaN      NaN
# 3                                                NaN           NaN      NaN
# 4                                                NaN           NaN      NaN
# 5                                                NaN           NaN      NaN
# 6                                                NaN           NaN      NaN
# 7                                                NaN           NaN      NaN
# 8                                                NaN           NaN      NaN
# 9                                                NaN           NaN      NaN
# 10                                               NaN           NaN      NaN
# 11                                               NaN           NaN      NaN
# 12                                               NaN           NaN      NaN
# 13                                               NaN           NaN      NaN
#
#                               Definition derived from  \
# 0                                                 NaN
# 1   https://www.merriam-webster.com/dictionary/dis...
# 2   https://www.merriam-webster.com/dictionary/sup...
# 3                                                 NaN
# 4   https://www.merriam-webster.com/dictionary/assume
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#    Priority \n(High, Medium, Low) Related to identifed concept
# 0                             NaN                     TIDO-C08
# 1                             NaN                     TIDO-C28
# 2                             NaN                     TIDO-C30
# 3                             NaN                     TIDO-C31
# 4                             NaN                          NaN
# 5                             NaN                          NaN
# 6                             NaN                          NaN
# 7                             NaN                          NaN
# 8                             NaN                          NaN
# 9                             NaN                          NaN
# 10                            NaN                          NaN
# 11                            NaN                          NaN
# 12                            NaN                          NaN
# 13                            NaN                          NaN

# %%
# Create an RDF graph
g = Graph()

# Define the rdfs namespace
# DC = Namespace("http://purl.org/dc/terms/")
# RDFS = Namespace("http://www.w3.org/2000/01/rdf-schema#")
TIDO = Namespace("https://w3id.org/tido#")
# SKOS = Namespace("http://www.w3.org/2004/02/skos/core#")

# Bind the TIDO namespace to the graph
g.bind("tido", TIDO)

# Load the existing TIDO.ttl file into the graph
try:
    g.parse("TIDO.ttl", format="turtle")
except FileNotFoundError:
    print("TIDO.ttl not found. A new file will be created.")

# Iterate through the Class DataFrame and create triples
for _, row in df_class.iterrows():
    class_uri = row['Class URI']
    definition = row['Definition']
    reference = row['Definition derived from']
    labels = row['Label(s)']

    if pd.notna(class_uri):  # Ensure values are not NaN
        subject = TIDO[class_uri.split(':')[1]]
        
        if pd.notna(definition):
            triple = (subject, RDFS.comment, Literal(definition))
            if triple not in g:  # Check for duplicate
                g.add(triple)
        
        if pd.notna(reference):
            triple = (subject, RDFS.isDefinedBy, Literal(reference))
            if triple not in g:  # Check for duplicate
                g.add(triple)
        
        if pd.notna(labels):
            for l in labels.split(','):
                if (subject, RDFS.label, Literal(l.strip())) not in g:  # Check for duplicate
                    g.add((subject, SKOS.altLabel, Literal(l.strip())))


# Iterate through the Property DataFrame and create triples
for _, row in df_property.iterrows():
    property_uri = row['Relation']
    definition = row['Definition']
    reference = row['Definition derived from']
    labels = row['Label(s)']

    if pd.notna(property_uri):  # Ensure values are not NaN
        subject = TIDO[property_uri.split(':')[1]]
        
        if pd.notna(definition):
            triple = (subject, RDFS.comment, Literal(definition))
            if triple not in g:  # Check for duplicate
                g.add(triple)
        
        if pd.notna(reference):
            triple = (subject, RDFS.seeAlso, Literal(reference))
            if triple not in g:  # Check for duplicate
                g.add(triple)
        
        if pd.notna(labels):
            for l in labels.split(','):
                if (subject, RDFS.label, Literal(l.strip())) not in g:  # Check for duplicate
                    g.add((subject, SKOS.altLabel, Literal(l.strip())))

# Serialize the graph to an RDF format (e.g., Turtle)
rdf_output = g.serialize(format='turtle') #.decode('utf-8')

# Save the RDF output to a file
with open("TIDO_enriched.ttl", "w") as f:
    f.write(rdf_output)

# Print the RDF output
print(rdf_output)
# Out:
# @prefix : <https://w3id.org/tido#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix mod: <https://w3id.org/mod#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix urref: <http://eturwg.c4i.gmu.edu/files/ontologies/URREF_v5_dev.owl#> .
# @prefix vann: <http://purl.org/vocab/vann/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# dcterms:created a owl:AnnotationProperty .
#
# dcterms:description a owl:AnnotationProperty .
#
# dcterms:license a owl:AnnotationProperty .
#
# dcterms:title a owl:AnnotationProperty .
#
# vann:preferredNamespacePrefix a owl:AnnotationProperty .
#
# vann:preferredNamespaceUri a owl:AnnotationProperty .
#
# owl:versionIRI a owl:AnnotationProperty .
#
# owl:versionInfo a owl:AnnotationProperty .
#
# <https://w3id.org/tido> a owl:Ontology ;
#     dcterms:created "2025-05-07"^^xsd:date ;
#     dcterms:description "The TIDO ontology can be used to describe the decision processes within the threat intelligence domain"@en ;
#     dcterms:license <https://creativecommons.org/licenses/by/4.0/> ;
#     dcterms:title "The Threat Intelligence Decision Ontology"@en ;
#     vann:preferredNamespacePrefix "tido" ;
#     vann:preferredNamespaceUri : ;
#     owl:versionIRI <https://w3id.org/tido/1.0.0> ;
#     owl:versionInfo "1.0.0" ;
#     mod:createdWith <https://chowlk.linkeddata.es/> .
#
# :Agent a owl:Class ;
#     rdfs:label "Agent" ;
#     rdfs:comment "The tido:Agent class is directly inherited from PROV-O. Here, an agent is defined as something that bears some form of responsibility for an activity taking place, for the existence of an entity, or for another agent's activity" ;
#     rdfs:isDefinedBy "https://www.w3.org/TR/2013/REC-prov-o-20130430/#Agent" ;
#     rdfs:subClassOf prov:Agent .
#
# :Cost a owl:Class ;
#     rdfs:label "Cost" ;
#     rdfs:comment "The outlay or expenditure (as of effort or sacrifice) made to achieve an object" ;
#     rdfs:isDefinedBy "https://www.merriam-webster.com/dictionary/cost" ;
#     rdfs:subClassOf :Consideration .
#
# :Goal a owl:Class ;
#     rdfs:label "Goal" ;
#     rdfs:comment "A clearly directed intent or purpose" ;
#     rdfs:isDefinedBy "https://www.merriam-webster.com/dictionary/aim" ;
#     rdfs:subClassOf :Consideration .
#
# :answers a owl:ObjectProperty ;
#     rdfs:label "answers" ;
#     rdfs:comment "A piece of information can be used to answer a research question. This piece of information can be anything, as long as it can be expressed in a sentence" ;
#     rdfs:domain :PieceOfInformation ;
#     rdfs:range :RQ .
#
# :assumes a owl:ObjectProperty ;
#     rdfs:label "assumes" ;
#     rdfs:comment "A relationship indicating how an option would take an hypothesis as granted or true" ;
#     rdfs:domain :Option ;
#     rdfs:range :Hypothesis ;
#     rdfs:seeAlso "https://www.merriam-webster.com/dictionary/assume" .
#
# :disputes a owl:ObjectProperty ;
#     rdfs:label "disputes" ;
#     rdfs:comment "A relationship indicating how a piece of information calls into question or casts doubt upon a hypothesis" ;
#     rdfs:domain :PieceOfInformation ;
#     rdfs:range :Hypothesis ;
#     rdfs:seeAlso "https://www.merriam-webster.com/dictionary/dispute" ;
#     rdfs:subPropertyOf :providesInsightsInto .
#
# :hasConsideration a owl:ObjectProperty ;
#     rdfs:label "has consideration" ;
#     rdfs:comment "An option can have multiple considerations that help in deciding on whether on not to select that option" ;
#     rdfs:domain :Option ;
#     rdfs:range :Consideration .
#
# :hasContext a owl:ObjectProperty ;
#     rdfs:label "has context" ;
#     rdfs:comment "A relationship indicating how one piece of information provides relevant context to another piece of information." ;
#     rdfs:domain :PieceOfInformation ;
#     rdfs:range :PieceOfInformation .
#
# :informs a owl:ObjectProperty ;
#     rdfs:label "informs" ;
#     rdfs:comment "A relationship that indicates which options would aid answering a research question. " ;
#     rdfs:domain :Option ;
#     rdfs:range :RQ .
#
# :questions a owl:ObjectProperty ;
#     rdfs:label "questions" ;
#     rdfs:comment "A research question can be raised by a piece of information" ;
#     rdfs:domain :RQ ;
#     rdfs:range :PieceOfInformation .
#
# :supports a owl:ObjectProperty ;
#     rdfs:label "supports" ;
#     rdfs:comment "A relationship indicating how a piece of information provides a hypothesis with substantiation/to support with evidence or authority, making it more certain" ;
#     rdfs:domain :PieceOfInformation ;
#     rdfs:range :Hypothesis ;
#     rdfs:seeAlso "https://www.merriam-webster.com/dictionary/supports and https://www.merriam-webster.com/dictionary/corroborate" ;
#     rdfs:subPropertyOf :providesInsightsInto .
#
# :wasExecutedBy a owl:ObjectProperty ;
#     rdfs:label "was executed by" ;
#     rdfs:comment "Once an option is selected, it could be excecuted by an activity. " ;
#     rdfs:domain :Option ;
#     rdfs:range :Activity .
#
# :wasRecalledBy a owl:ObjectProperty ;
#     rdfs:label "was recalled by" ;
#     rdfs:comment "During an orientation step, no new informatoin is generated but only pre-existing information is recalled" ;
#     rdfs:domain :PieceOfInformation ;
#     rdfs:range :Orientation .
#
# :wasSelectedBy a owl:ObjectProperty ;
#     rdfs:label "was selected by" ;
#     rdfs:comment "An option can be selected during a resolution step. This selection of an option is what constitudes a decision." ;
#     rdfs:domain :Option ;
#     rdfs:range :Resolution .
#
# urref:Information a owl:Class ;
#     rdfs:label "Information" .
#
# prov:Activity a owl:Class ;
#     rdfs:label "Activity" .
#
# prov:Agent a owl:Class ;
#     rdfs:label "Agent" .
#
# prov:Collection a owl:Class ;
#     rdfs:label "Collection" .
#
# prov:Entity a owl:Class ;
#     rdfs:label "Entity" .
#
# prov:wasMemberOf a owl:ObjectProperty ;
#     rdfs:label "was member of" .
#
# :Evidence a owl:Class ;
#     rdfs:label "Evidence" ;
#     rdfs:comment "A piece of information that is either a testamony, an observation, or a sensory measurement." ;
#     rdfs:isDefinedBy "http://eturwg.c4i.gmu.edu/files/ontologies/URREF#SingularEvidence" ;
#     rdfs:subClassOf :PieceOfInformation ;
#     owl:disjointWith :Hypothesis .
#
# :Orientation a owl:Class ;
#     rdfs:label "Orientation" ;
#     rdfs:comment "A step in the decision process where available information is shared, repeated, clarified or confirmed." ;
#     rdfs:isDefinedBy "Bales' 1st phase of group-decision making" ;
#     rdfs:subClassOf :Activity ;
#     skos:altLabel "Orientation step" .
#
# :Resolution a owl:Class ;
#     rdfs:label "Resolution" ;
#     rdfs:comment "A step in the decision process where a possible direction is chosen" ;
#     rdfs:isDefinedBy "Bales' 3rd phase of group decision making" ;
#     rdfs:subClassOf :Activity ;
#     skos:altLabel "Resolution step" .
#
# :contributesTo a owl:ObjectProperty ;
#     rdfs:label "contributes to" ;
#     rdfs:comment "Every activity should contribute to one or more cases/investigations. " ;
#     rdfs:domain :Activity ;
#     rdfs:range :Case .
#
# :investigates a owl:ObjectProperty ;
#     rdfs:label "investigates" ;
#     rdfs:comment "An investigation, or case, investigates one or more research questions" ;
#     rdfs:domain :Case ;
#     rdfs:range :RQ .
#
# :providesInsightsInto a owl:ObjectProperty ;
#     rdfs:label "provides insights into" ;
#     rdfs:comment "The super-property of tido:supports and tido:disputes" ;
#     rdfs:domain :PieceOfInformation ;
#     rdfs:range :Hypothesis ;
#     skos:altLabel "provides insight into" .
#
# :Consideration a owl:Class ;
#     rdfs:label "Consideration" ;
#     rdfs:comment "A matter weighed or taken into account when formulating an opinion or plan" ;
#     rdfs:isDefinedBy "https://www.merriam-webster.com/dictionary/consideration" ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onClass :Evaluation ;
#             owl:onProperty prov:wasGeneratedBy ;
#             owl:qualifiedCardinality "1"^^xsd:nonNegativeInteger ],
#         :PieceOfInformation .
#
# prov:wasGeneratedBy a owl:ObjectProperty ;
#     rdfs:label "was generated by" .
#
# :Case a owl:Class ;
#     rdfs:label "Case" ;
#     rdfs:comment "A collection of pieces of information that were recalled, inferred, deduced or produced during an investigation. " ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:minQualifiedCardinality "1"^^xsd:nonNegativeInteger ;
#             owl:onClass :RQ ;
#             owl:onProperty :investigates ],
#         prov:Collection ;
#     skos:altLabel "Investigation" .
#
# :Evaluation a owl:Class ;
#     rdfs:label "Evaluation" ;
#     rdfs:comment "A step in the decision process where opinions, evaluations and analysis are expressed. " ;
#     rdfs:isDefinedBy "Bales' 2nd phase of group-decision making" ;
#     rdfs:subClassOf :Activity ;
#     skos:altLabel "Evaluation step" .
#
# :Activity a owl:Class ;
#     rdfs:label "Activity" ;
#     rdfs:comment "The tido:Activity class is directly inherited from PROV-O. Here, an activity is defined as something that occurs over a period of time and acts upon or with pieces of information; it may include consuming, processing, transforming, modifying, relocating, using, or generating pieces of information." ;
#     rdfs:isDefinedBy "https://www.w3.org/TR/2013/REC-prov-o-20130430/#Action" ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:minQualifiedCardinality "1"^^xsd:nonNegativeInteger ;
#             owl:onClass :Case ;
#             owl:onProperty :contributesTo ],
#         prov:Activity .
#
# :Hypothesis a owl:Class ;
#     rdfs:label "Hypothesis" ;
#     rdfs:comment "A possible interpretation of the availble information that forms the ground for further action. Other pieces of information could be used to either support or dispute a hypothesis." ;
#     rdfs:isDefinedBy "https://www.merriam-webster.com/dictionary/hypothesis" ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onClass :Evaluation ;
#             owl:onProperty prov:wasGeneratedBy ;
#             owl:qualifiedCardinality "1"^^xsd:nonNegativeInteger ],
#         :PieceOfInformation ;
#     owl:disjointWith :Evidence .
#
# :Option a owl:Class ;
#     rdfs:label "Option" ;
#     rdfs:comment "Something that could be chosen. In the domain of Threat Intelligence, this could mean a course of action, but also an assesment of the situation or the answer to a research question." ;
#     rdfs:isDefinedBy "https://www.merriam-webster.com/dictionary/option" ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onClass :Evaluation ;
#             owl:onProperty prov:wasGeneratedBy ;
#             owl:qualifiedCardinality "1"^^xsd:nonNegativeInteger ],
#         :PieceOfInformation .
#
# :RQ a owl:Class ;
#     rdfs:label "R Q" ;
#     rdfs:comment "A question that arrises during an investigation." ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:onClass :Evaluation ;
#             owl:onProperty prov:wasGeneratedBy ;
#             owl:qualifiedCardinality "1"^^xsd:nonNegativeInteger ],
#         :PieceOfInformation ;
#     skos:altLabel "RQ",
#         "Research question" .
#
# :PieceOfInformation a owl:Class ;
#     rdfs:label "Piece Of Information" ;
#     rdfs:comment "The term “piece of information” is used in this paper in its most general meaning covering other notions such as evidence, knowledge and/or data. A piece of information can be as simple as a measurement (on the scale of real numbers) but could be a fact (i.e., an observation, known to be true), an uncertain statement already modeled into a given mathematical formalism (i.e., a probability distribution), an unstructured statement in natural language" ;
#     rdfs:isDefinedBy "URREF (Costa et al. 2018)" ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:minQualifiedCardinality "1"^^xsd:nonNegativeInteger ;
#             owl:onClass :Case ;
#             owl:onProperty prov:wasMemberOf ],
#         urref:Information,
#         prov:Entity ;
#     skos:altLabel "Piece of information",
#         "PoI",
#         "Sentence" .

# %%
df_files = [
    'transcriptions/dataframes/De_Dienst_ep_1.csv',
    'transcriptions/dataframes/De_Dienst_ep_2.csv',
    # 'transcriptions/dataframes/De_Dienst_ep_3.csv',
    # 'transcriptions/dataframes/De_Dienst_ep_4.csv',
    # 'transcriptions/dataframes/De_Dienst_ep_5.csv',
    # 'transcriptions/dataframes/De_Dienst_ep_6.csv',
]

column_to_rdf_mapping = {
    'start': PROV.startedAtTime,
    'end': PROV.endedAtTime,
    'speaker': PROV.wasAssociatedWith,
    'transcription': (RDF.value, "@nl"),
    'translation': (RDF.value, "@en"),
}

# Read and concatenate all files into a single DataFrame
all_dataframes = [pd.read_csv(file, sep=';') for file in df_files]
combined_di_dataframe = pd.concat(all_dataframes, ignore_index=True)

# Drop the 'Unnamed: 0' column
if 'Unnamed: 0' in combined_di_dataframe.columns:
    combined_di_dataframe = combined_di_dataframe.drop(columns=['Unnamed: 0'])

# Display the combined DataFrame
print(combined_di_dataframe)
# Out:
#                      seg_id                start                  end  \
# 0      De_Dienst_ep_1_seg_0  2025-01-01 00:00:00  2025-01-01 00:00:21
# 1      De_Dienst_ep_1_seg_1  2025-01-01 00:00:30  2025-01-01 00:01:11
# 2      De_Dienst_ep_1_seg_2  2025-01-01 00:01:11  2025-01-01 00:01:25
# 3      De_Dienst_ep_1_seg_3  2025-01-01 00:01:27  2025-01-01 00:01:43
# 4      De_Dienst_ep_1_seg_4  2025-01-01 00:01:43  2025-01-01 00:01:44
# ..                      ...                  ...                  ...
# 223  De_Dienst_ep_2_seg_117  2025-01-02 00:23:50  2025-01-02 00:24:03
# 224  De_Dienst_ep_2_seg_118  2025-01-02 00:24:04  2025-01-02 00:24:09
# 225  De_Dienst_ep_2_seg_119  2025-01-02 00:24:13  2025-01-02 00:24:33
# 226  De_Dienst_ep_2_seg_120  2025-01-02 00:24:37  2025-01-02 00:25:07
# 227  De_Dienst_ep_2_seg_121  2025-01-02 00:25:07  2025-01-02 00:25:20
#
#       speaker                                      transcription  \
# 0        Bart   De eerste keer dat ik een telefoon tap, dat i...
# 1    Liesbeth   Zoals vrijwel iedereen in Nederland ben ik on...
# 2        Bart   Er is een melding binnengekomen. Tijdens een ...
# 3    Liesbeth   Je hoort de stem van Bart. Hij is teamhoofd b...
# 4        Bart                               Kan ik je vertellen?
# ..        ...                                                ...
# 223    Andrea   Ja, en zo'n huisgenoot die, als het goed is.....
# 224  Liesbeth   En het kan ook zomaar zijn dat hier nu uitkom...
# 225    Andrea   Dan ga je weer terug. Ze merken geen verander...
# 226  Liesbeth   Oké, dag twee. Weer een hele hoop informatie....
# 227      Bart   omdat er toch nog wat interessants gekomen is...
#
#                                            translation
# 0     The first time I heard a phone call, that I c...
# 1     Like almost everyone in the Netherlands, I am...
# 2     A message has arrived. During a practice, it ...
# 3     You can hear Bart's voice. He is head of the ...
# 4                        I find it all quite exciting.
# ..                                                 ...
# 223   What is a series of things? Yes, and such a r...
# 224   And it can also just be that it turns out her...
# 225   Yes. Then you go back. They notice no change....
# 226   Okay, day two. A lot of information again. It...
# 227   Hey Liesbeth, this is Bart. I'll call you at ...
#
# [228 rows x 6 columns]

# %%
from rdflib import Graph, Namespace

# Define namespaces
# RDFS = Namespace("http://www.w3.org/2000/01/rdf-schema#")
# RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
TIDO = Namespace("https://w3id.org/tido#")
TIDO_case = Namespace("https://w3id.org/tido/case#")
PROV = Namespace("http://www.w3.org/ns/prov#")
# SKOS = Namespace("http://www.w3.org/2004/02/skos/core#")

def add_triple(graph, triple):
    """
    Add a triple to the graph if it doesn't already exist.
    """
    if triple not in graph:
        graph.add(triple)

# Create an RDF graph
g_TIDO = Graph()
g_TIDO.bind("tido", TIDO)

# Load the TIDO_enriched.ttl file into the graph
try:
    g_TIDO.parse("TIDO_enriched.ttl", format="turtle")
    print("TIDO_enriched.ttl loaded successfully.")
except FileNotFoundError:
    print("TIDO_enriched.ttl not found.")


DIs = [
    'di01',
    'di02',
    # 'di03',
    # 'di04',
    # 'di05',
    # 'di06',
    # 'di07',
    # 'di08',
    # 'di09',
    # 'di10'
    ]

for di in DIs:
    di_ns = Namespace(f"https://w3id.org/tido/{di}#")
    # Create an RDF graph
    g_DI = Graph()
    g_DI.bind(di, di_ns)
    g_DI.bind("tido", TIDO)
    g_DI.bind("tido_case", TIDO_case)

    # Load the original DI01.ttl file into the graph
    try:
        g_DI.parse(f"./DIs/original/tido_{di}.ttl", format="turtle")
        print(f"./DIs/original/tido_{di}.ttl loaded successfully.")
    except FileNotFoundError:
        print(f"./DIs/original/tido_{di}.ttl not found.")

    # g_DI += g_TIDO

    # Implement basic rdfs:subclassOf inference
    for s1,p,o in g_TIDO.triples((None, RDFS.subClassOf, TIDO.Activity)):
        for s2, _, _ in g_DI.triples((None, RDF.type, s1)):
            triple = (s2, RDF.type, o)
            add_triple(g_DI, triple)

    for s,_,_ in g_DI.triples((None, RDF.type, TIDO.Activity)):
        for s1, _, o1 in g_DI.triples((s, RDFS.label, None)):

            # For every s1, retrieve the corresponding row from combined_di_dataframe using o1 as seg_id
            seg_id = str(o1)
            seg_row = combined_di_dataframe[combined_di_dataframe['seg_id'] == seg_id]
            
            if not seg_row.empty:
                # add a triple to g_DI using the prov:startedAtTime property and the start from seg_row
                start_time = seg_row.iloc[0]['start']
                triple = (s, PROV.startedAtTime, Literal(start_time, datatype=XSD.dateTime))
                add_triple(g_DI, triple) 
            
                # add a triple to g_DI using the prov:endedAtTime property and the end from seg_row
                end_time = seg_row.iloc[0]['end']
                triple = (s, PROV.endedAtTime, Literal(end_time, datatype=XSD.dateTime))
                add_triple(g_DI, triple) 

                # add a triple to g_DI using the prov:wasAssociatedWith property and the agent_uri
                # check if an agent with the same name exists in g_DI
                # if not, create a new agent
                agent_names = seg_row.iloc[0]['speaker']

                for agent_name in agent_names.split(','):
                    # remove leading and trailing spaces
                    agent_name = agent_name.strip()
                    # replace spaces with underscores
                    agent_name = agent_name.replace(" ", "_")
                    # remove special characters
                    agent_name = ''.join(e for e in agent_name if e.isalnum() or e == '_')
                    # replace multiple underscores with a single underscore
                    agent_name = '_'.join(agent_name.split('_'))
                    # remove leading and trailing underscores
                    agent_name = agent_name.strip('_')
                    # create a uri for the agent in the DI01 namespace
                    agent_uri = TIDO_case[agent_name.lower()]
                    # Check if the agent already exists in g_DI as an agent
                    if (agent_uri, RDF.type, TIDO.Agent) not in g_DI:
                        triple = (agent_uri, RDF.type, TIDO.Agent)
                        add_triple(g_DI, triple)
                    
                    # make sure only first letter is capitalized of the agent name
                    agent_name = agent_name.capitalize()
                    triple = (agent_uri, RDFS.label, Literal(agent_name))
                    if triple not in g_DI:
                        add_triple(g_DI, triple)
                
                    # add a triple to g_DI using the prov:wasAssociatedWith property and the agent_uri
                    triple = (s, PROV.wasAssociatedWith, agent_uri)
                    if triple not in g_DI:
                        add_triple(g_DI, triple)

                # Add the transcription and translation to g_DI
                # add a triple to g_DI using the rdf:value property and the transcription from seg_row
                transcription = seg_row.iloc[0]['transcription']
                if pd.notna(transcription):
                    triple = (s, RDF.value, Literal(transcription, lang="nl"))
                    add_triple(g_DI, triple)
                # add a triple to g_DI using the rdf:value property and the translation from seg_row
                translation = seg_row.iloc[0]['translation']
                if pd.notna(translation):
                    triple = (s, RDF.value, Literal(translation, lang="en"))
                    add_triple(g_DI, triple)
                
                triple = (s, TIDO.contributesTo, TIDO_case["case_1"])
                if triple not in g_DI:
                    add_triple(g_DI, triple)
            else:
                raise ValueError(f"No matching row found for seg_id: {seg_id}")

    # Serialize the graph to an RDF format (e.g., Turtle)
    rdf_output = g_DI.serialize(format='turtle') #.decode('utf-8')

    # Save the RDF output to a file
    with open(f"DIs/extended/tido_{di}.ttl", "w") as f:
        f.write(rdf_output)

    # Print the RDF output
    # print(rdf_output)

            # Check if the 
            # triple already exists in g_DI
            # if triple not in g_DI:
# Out:
# TIDO_enriched.ttl loaded successfully.
# ./DIs/original/tido_di01.ttl loaded successfully.
# ./DIs/original/tido_di02.ttl loaded successfully.
